# %% [markdown]
# # Breve Tutorial de Markdown
#
# Markdown es un lenguaje de marcado que facilita la aplicación de formato a un texto empleando una serie de caracteres de una forma especial. En principio, fue pensado para elaborar textos cuyo destino iba a ser la web con más rapidez y sencillez que si estuviésemos empleando directamente HTML. Y si bien ese suele ser el mejor uso que podemos darle, también podemos emplearlo para cualquier tipo de texto, independientemente de cual vaya a ser su destino.
#
# Jupyter tiene una implementación del lenguaje de marcado markdown  que puede ser insertado en celdas con formato markdown para crear formato de texto y documentación en notebook.
#
#
# ## Markdown
#
# ### Encabezados
#
# ## E1
# ### E2
# ### E3
# #### E4
# ##### E5
# ###### E6
#
# **Código:**
# ```markdown
# # E1
# ## E2
# ### E3
# #### E4
# ##### E5
# ###### E6
# ```
#
# ## Encabezados alternativos
#
#
# Encabezado 1
# =========
#
# Encabezado 2
# ----------
#
# **Código:**
# ```markdown
# Heading 1
# =========
#
# Heading 2
# ---------
# ```
#
# ## Estilos de fuente
#
# **Bold Font** or __Bold Font__
#
# *Italic* or _Italic Font_
#
#  ~~Scratched Text~~
#
# Markdown no soporta subrayado, pero puede usarse HTML <u>Text</u>
#
# **Código:**
#  ```markdown
# **Bold Font** or __Bold Font__
# *Italic* or _Italic Font_
# ~~Scratched Text~~
#
# Markdown no soporta subrayado, pero puede usarse HTML <u>Text</u>
# ```
# ## Listas
#
# - item
# - item
#  - subitem
#  - subitem
# - item
#
#
# 1. item
# 2. item
#  1. sub item
#  2. sub item
# 3. item
#
# **Código:**
# ```markdown
# - item
# - item
#  - subitem
#  - subitem
# - item
#
#
# 1. item
# 2. item
#   1. sub item
#   2. sub item
# 3. item
# ```
# ## Links
#
# http://www.github.com/
#
# [Github](http://www.github.com/)
#
# **Código:**
# ```
# http://www.github.com/
#
# [Github](http://www.github.com/)
# ```
#
# ## Imágenes
# ![Turing's Device](http://www.google.com/logos/2012/turing-doodle-static.jpg "Alan Turing's 100th Birthday")
#
# **Código:**
# ```markdown
# ![Turing's Device](http://www.google.com/logos/2012/turing-doodle-static.jpg "Alan Turing's 100th Birthday")
# ```
# ## Citas
#
# > Why, oh why, Javascript??? Wars, famine, planetary destruction... I guess as a species, we deserve this abomination...
# >
# > [Fernando Perez](https://twitter.com/fperez_org)
#
# **Código:**
# ```
# > Why, oh why, Javascript??? Wars, famine, planetary destruction... I guess as a species, we deserve this abomination...
# >
# > [Fernando Perez](https://twitter.com/fperez_org)
# ```
#
# ## Línea Horizontal
#
# ---
#
# **Código::**
# ```markdown
# ---
# ```
#
# ## Tablas
#
# | Tables        | Are           | Cool  |
# | :------------ |:-------------:| -----:|
# | col 3 is      | right-aligned |  1600 |
# | col 2 is      | centered      |    12 |
# | zebra stripes | are neat      |     1 |
#
# **Código:**
# ```
# | Tables        | Are           | Cool  |
# |:------------- |:-------------:| -----:|
# | col 3 is      | right-aligned |  1600 |
# | col 2 is      | centered      |    12 |
# | zebra stripes | are neat      |     1 |
# ```
#
# ## HTML
#
# <b>Puedes</b> cambiar <i>casi</i> cualquier código <span style="color:red;">HTML</span> que <u>gustes</u>.
#
# **Código:**
#
# ```
# <b>Puedes</b> cambiar <i>casi</i> cualquier código <span style="color:red;">HTML</span> que <u>gustes</u>.
# ```
# ## Código
#
# Puedes adicionar en línea código como: `import numpy as np`
#
# O código en bloque:
#
# Código Python:
# ```python
# x = 5
# print "%.2f" % x
# ```
# Código Java Script:
# ```javascript
# x = 5
# alert(x);
# ```
#
# **Código:**
# <pre>
# Código Python:
# ```python
# x = 5
# print "%.2f" % x
# ```
# Código Java Script:
# ```javascript
# x = 5
# alert(x);
# ```
# </pre>
#
# ## ACTIVIDADES
#
# Revisar [queesmarkdown](https://www.silocreativo.com/que-es-markdown-por-que-deberias-empezar-a-usarlo/)
